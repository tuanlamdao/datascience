# %% [markdown]
# <a href="https://colab.research.google.com/github/tuanlamdao/datascience/blob/master/Lines_and_planes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lines and planes

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
number_people = np.arange(1,11) # 1 - 10 people
number_rbs    = np.arange(0,20) # 0 - 19 root beers
number_people, number_rbs = np.meshgrid(number_people, number_rbs)
total_cost = 80 * number_people + 10 * number_rbs + 40

# %%
from mpl_toolkits.mplot3d import Axes3D
fig, axes = plt.subplots(2,3,subplot_kw={'projection':'3d'},figsize=(9,6))
angles = [0,45,90,135,180]
for ax, angle in zip(axes.flat, angles):
    ax.plot_surface(number_people, number_rbs, total_cost)
    ax.set_xlabel("People")
    ax.set_ylabel("RootBeers")
    ax.set_zlabel("TotalCost")
    ax.azim = angle
    axes.flat[-1].axis('off')
plt.show()
